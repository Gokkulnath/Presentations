# %%
# !pip install pexpect

# %%
import pexpect
import pty
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-d9f86b1a7c60> in <module>
#       1 import pexpect
# ----> 2 import pty
#
# ~\AppData\Local\Continuum\anaconda3\lib\pty.py in <module>
#       9 from select import select
#      10 import os
# ---> 11 import tty
#      12
#      13 __all__ = ["openpty","fork","spawn"]
#
# ~\AppData\Local\Continuum\anaconda3\lib\tty.py in <module>
#       3 # Author: Steen Lumholt.
#       4
# ----> 5 from termios import *
#       6
#       7 __all__ = ["setraw", "setcbreak"]
#
# ModuleNotFoundError: No module named 'termios'

# %%
from __future__ import absolute_import
from __future__ import print_function
from __future__ import unicode_literals
from pexpect import *


# Don't do this unless you like being John Malkovich
# c = pexpect.spawnu('/usr/bin/env python ./python.py')

# Note that, for Python 3 compatibility reasons, we are using spawnu and
# importing unicode_literals (above). spawnu accepts Unicode input and
# unicode_literals makes all string literals in this script Unicode by default.
c =  pexpect.popen_spawn.PopenSpawn('python', timeout=1)


c.expect('>>>')
print('And now for something completely different...')
print(''.join(reversed((c.before))))
print('Yes, it\'s python, but it\'s backwards.')
print()
print('Escape character is \'^]\'.')
print(c.after, end=' ')
c.interact()
c.kill(1)
print('is alive:', c.isalive())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-cc23cbe3747d> in <module>
#       2 from __future__ import print_function
#       3 from __future__ import unicode_literals
# ----> 4 from pexpect import *
#       5
#       6
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pexpect\run.py in <module>
#       3
#       4 from .exceptions import EOF, TIMEOUT
# ----> 5 from .pty_spawn import spawn
#       6
#       7 def run(command, timeout=30, withexitstatus=False, events=None,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pexpect\pty_spawn.py in <module>
#       2 import sys
#       3 import time
# ----> 4 import pty
#       5 import tty
#       6 import errno
#
# ~\AppData\Local\Continuum\anaconda3\lib\pty.py in <module>
#       9 from select import select
#      10 import os
# ---> 11 import tty
#      12
# ...

# %%
dir(pexpect)
# Out:
# ['EOF',
#  'ExceptionPexpect',
#  'Expecter',
#  'PY3',
#  'TIMEOUT',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__revision__',
#  '__spec__',
#  '__version__',
#  'exceptions',
#  'expect',
#  'is_executable_file',
#  'searcher_re',
#  'searcher_string',
#  'split_command_line',
#  'sys',
#  'utils',
#  'which']

# %%
from lxml import html

import requests

# %%
URL='https://www.ganeshaspeaks.com/horoscopes/daily-horoscope/{}/'.format('gemini')
daily_preds='//p[@class="margin-top-xs-0"]/text()'
pageContent=requests.get(URL)
pageContent.content
# Out:
# b'\n\n<!DOCTYPE html>\n<html lang="en">\n<head>\n<meta charset="UTF-8"/>  \n    <title>Gemini Daily Horoscope - Today&#039;s Gemini Horoscope for Free | GaneshaSpeaks.com</title>\n<link rel="manifest" href="https://www.ganeshaspeaks.com/manifest.json">\n\n<!-- This site is optimized with the Yoast SEO Premium plugin v4.8 - https://yoast.com/wordpress/plugins/seo/ -->\n<meta name="description" content="Get your daily Gemini astrology from Ganesha speaks. We are your Free Daily Gemini horoscope source. Get your Free Gemini Horoscope for today, love horoscopes, zodiac sign profiles."/>\n<meta name="robots" content="noodp"/>\n<meta property="og:locale" content="en_US" />\n<meta property="og:type" content="article" />\n<meta property="og:title" content="Gemini Daily Horoscope - Today&#039;s Gemini Horoscope for Free | GaneshaSpeaks.com" />\n<meta property="og:description" content="Get your daily Gemini astrology from Ganesha speaks. We are your Free Daily Gemini horoscope source. Get your
# ...

# %%
import lxml
from lxml import

# %%
tree = html.fromstring(pageContent.content)
print(tree.xpath(daily_preds)[0].strip())
# Out:
# You will be able to express your thoughts and opinions to the people you come in contact with today. They will also reciprocate and echo your feelings and emotions. This will give you validation and satisfaction. The day should be filled with fun and entertainment overall, says Ganesha.

# %%
import pandas as pd
my={"Column1":[[2,3],[4,7,8],[2],[4,5,2,6,2],[2,1 ]]}

df=pd.Series(my)
df
# Out:
# Column1    [[2, 3], [4, 7, 8], [2], [4, 5, 2, 6, 2], [2, 1]]
# dtype: object

# %%
import numpy as np
df.apply(lambda x : np.max(x))
# Out:
# Column1    [4, 7, 8]
# dtype: object

# %%
for item in df:
    print(np.max(np.array(df)))
# Out:
# [[2, 3], [4, 7, 8], [2], [4, 5, 2, 6, 2], [2, 1]]
